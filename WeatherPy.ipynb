# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
import requests
import datetime as dt
import seaborn as sns

# %%
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#len(cities)
# Out:
# 610

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=b93d39364f506080e4b83532222dd9b2&q='

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
citynew =[]
cloudiness =[]
dates =[]
humidities =[]
lats =[]
lngs =[]
maxtemps =[]
windspeed =[]
countries =[]
counter=1
city_name=[]
test_city=["rikitea", "saint-pierre", "mataura", "hilo", "vic", "timra"]





for city in cities:
    try:
        url = "http://api.openweathermap.org/data/2.5/weather?"
        s=url + "appid=" + weather_api_key + "&q=" + city
        response = requests.get(s).json()
        #print (each)
        #print (response ["name"])
        citynew.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        countries.append(response["sys"]["country"])
        dates.append(response["dt"])
        humidities.append(response["main"]["humidity"])
        maxtemps.append(response["main"]["temp_max"])
        lats.append(response["coord"]["lat"])
        lngs.append(response["coord"]["lon"])
        windspeed.append(response["wind"]["speed"])
        city_name = response["name"]
    except:
        print(f"city not found")
        
        
        time.sleep(1.00)
        counter=counter+1
        
        
    print(f"{counter}/{city}")
    print(f"{url}&q={city}")
# Out:
# city not found
# 2/taolanaro
# http://api.openweathermap.org/data/2.5/weather?&q=taolanaro
# 2/malatya
# http://api.openweathermap.org/data/2.5/weather?&q=malatya
# 2/rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# 2/alta floresta
# http://api.openweathermap.org/data/2.5/weather?&q=alta floresta
# 2/ilhabela
# http://api.openweathermap.org/data/2.5/weather?&q=ilhabela
# 2/grants pass
# http://api.openweathermap.org/data/2.5/weather?&q=grants pass
# 2/avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# 2/iquique
# http://api.openweathermap.org/data/2.5/weather?&q=iquique
# 2/hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# city not found
# 3/chagda
# http://api.openweathermap.org/data/2.5/weather?&q=chagda
# 3/busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# 3/raduzhnyy
# http://api.openweathermap.org/data/2.5/weather?&q=raduzhnyy
# 3/jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# 3/port alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# 3/pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# 3/cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# 3/khunti
# http://api.openweathermap.org/data/2.5/weather?&q=khunti
# 3/gushikawa
# http://api.openweathermap.org/data/2.5/weather?&q=gushikawa
# 3/cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# 3/sakakah
# http://api.openweathermap.org/data/2.5/weather?&q=sakakah
# 3/vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# 3/tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# 3/faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# 3/constitucion
# http://api.openweathermap.org/data/2.5/weather?&q=constitucion
# 3/kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# 3/ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# 3/hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# 3/tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# 3/emerald
# http://api.openweathermap.org/data/2.5/weather?&q=emerald
# 3/murchison
# http://api.openweathermap.org/data/2.5/weather?&q=murchison
# 3/ribeira grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# 3/mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# 3/nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# 3/buloh kasap
# http://api.openweathermap.org/data/2.5/weather?&q=buloh kasap
# 3/bulach
# http://api.openweathermap.org/data/2.5/weather?&q=bulach
# 3/barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# 3/souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# 3/luderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# 3/upata
# http://api.openweathermap.org/data/2.5/weather?&q=upata
# 3/narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# 3/yar-sale
# http://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# 3/sao filipe
# http://api.openweathermap.org/data/2.5/weather?&q=sao filipe
# 3/coquimbo
# http://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# 3/buala
# http://api.openweathermap.org/data/2.5/weather?&q=buala
# 3/mishelevka
# http://api.openweathermap.org/data/2.5/weather?&q=mishelevka
# 3/bahawalpur
# http://api.openweathermap.org/data/2.5/weather?&q=bahawalpur
# 3/albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# 3/castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# 3/baillif
# http://api.openweathermap.org/data/2.5/weather?&q=baillif
# 3/tautira
# http://api.openweathermap.org/data/2.5/weather?&q=tautira
# 3/dukat
# http://api.openweathermap.org/data/2.5/weather?&q=dukat
# 3/aksu
# http://api.openweathermap.org/data/2.5/weather?&q=aksu
# 3/yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# city not found
# 4/crab hill
# http://api.openweathermap.org/data/2.5/weather?&q=crab hill
# 4/bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# 4/clyde river
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# city not found
# 5/belushya guba
# http://api.openweathermap.org/data/2.5/weather?&q=belushya guba
# 5/hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# 5/flin flon
# http://api.openweathermap.org/data/2.5/weather?&q=flin flon
# 5/morehead
# http://api.openweathermap.org/data/2.5/weather?&q=morehead
# 5/turek
# http://api.openweathermap.org/data/2.5/weather?&q=turek
# 5/kaifeng
# http://api.openweathermap.org/data/2.5/weather?&q=kaifeng
# 5/torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# 5/male
# http://api.openweathermap.org/data/2.5/weather?&q=male
# 5/comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?&q=comodoro rivadavia
# 5/ancud
# http://api.openweathermap.org/data/2.5/weather?&q=ancud
# 5/saint-philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# 5/nguru
# http://api.openweathermap.org/data/2.5/weather?&q=nguru
# 5/thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# 5/victoria
# http://api.openweathermap.org/data/2.5/weather?&q=victoria
# 5/kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# 5/severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# 5/rio gallegos
# http://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# 5/puerto penasco
# http://api.openweathermap.org/data/2.5/weather?&q=puerto penasco
# 5/hovd
# http://api.openweathermap.org/data/2.5/weather?&q=hovd
# 5/sainte-maxime
# http://api.openweathermap.org/data/2.5/weather?&q=sainte-maxime
# 5/inza
# http://api.openweathermap.org/data/2.5/weather?&q=inza
# 5/naze
# http://api.openweathermap.org/data/2.5/weather?&q=naze
# 5/impfondo
# http://api.openweathermap.org/data/2.5/weather?&q=impfondo
# 5/garmisch-partenkirchen
# http://api.openweathermap.org/data/2.5/weather?&q=garmisch-partenkirchen
# 5/koregaon
# http://api.openweathermap.org/data/2.5/weather?&q=koregaon
# 5/murgab
# http://api.openweathermap.org/data/2.5/weather?&q=murgab
# 5/gigmoto
# http://api.openweathermap.org/data/2.5/weather?&q=gigmoto
# 5/portland
# http://api.openweathermap.org/data/2.5/weather?&q=portland
# city not found
# 6/vaitupu
# http://api.openweathermap.org/data/2.5/weather?&q=vaitupu
# 6/new norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# 6/kovdor
# http://api.openweathermap.org/data/2.5/weather?&q=kovdor
# 6/manaus
# http://api.openweathermap.org/data/2.5/weather?&q=manaus
# 6/khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# 6/ponta do sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# 6/kochi
# http://api.openweathermap.org/data/2.5/weather?&q=kochi
# 6/kavieng
# http://api.openweathermap.org/data/2.5/weather?&q=kavieng
# 6/kununurra
# http://api.openweathermap.org/data/2.5/weather?&q=kununurra
# 6/punta arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# city not found
# 7/mocambique
# http://api.openweathermap.org/data/2.5/weather?&q=mocambique
# 7/matamoros
# http://api.openweathermap.org/data/2.5/weather?&q=matamoros
# 7/wollongong
# http://api.openweathermap.org/data/2.5/weather?&q=wollongong
# 7/muroto
# http://api.openweathermap.org/data/2.5/weather?&q=muroto
# 7/provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# city not found
# 8/amderma
# http://api.openweathermap.org/data/2.5/weather?&q=amderma
# 8/cape town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# 8/killybegs
# http://api.openweathermap.org/data/2.5/weather?&q=killybegs
# 8/puerto ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# 8/georgetown
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# 8/puerto quijarro
# http://api.openweathermap.org/data/2.5/weather?&q=puerto quijarro
# 8/bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# city not found
# 9/illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?&q=illoqqortoormiut
# 9/bontang
# http://api.openweathermap.org/data/2.5/weather?&q=bontang
# city not found
# 10/hire
# http://api.openweathermap.org/data/2.5/weather?&q=hire
# 10/xining
# http://api.openweathermap.org/data/2.5/weather?&q=xining
# 10/polunochnoye
# http://api.openweathermap.org/data/2.5/weather?&q=polunochnoye
# 10/emba
# http://api.openweathermap.org/data/2.5/weather?&q=emba
# 10/chimbote
# http://api.openweathermap.org/data/2.5/weather?&q=chimbote
# 10/nalut
# http://api.openweathermap.org/data/2.5/weather?&q=nalut
# 10/margate
# http://api.openweathermap.org/data/2.5/weather?&q=margate
# 10/monrovia
# http://api.openweathermap.org/data/2.5/weather?&q=monrovia
# 10/atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# 10/givors
# http://api.openweathermap.org/data/2.5/weather?&q=givors
# city not found
# 11/kerteh
# http://api.openweathermap.org/data/2.5/weather?&q=kerteh
# city not found
# 12/rawannawi
# http://api.openweathermap.org/data/2.5/weather?&q=rawannawi
# 12/namatanai
# http://api.openweathermap.org/data/2.5/weather?&q=namatanai
# 12/husavik
# http://api.openweathermap.org/data/2.5/weather?&q=husavik
# 12/havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?&q=havre-saint-pierre
# 12/laguna
# http://api.openweathermap.org/data/2.5/weather?&q=laguna
# 12/lagoa
# http://api.openweathermap.org/data/2.5/weather?&q=lagoa
# 12/haines junction
# http://api.openweathermap.org/data/2.5/weather?&q=haines junction
# 12/ulladulla
# http://api.openweathermap.org/data/2.5/weather?&q=ulladulla
# 12/saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# 12/udachnyy
# http://api.openweathermap.org/data/2.5/weather?&q=udachnyy
# 12/saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# 12/airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# 12/assiniboia
# http://api.openweathermap.org/data/2.5/weather?&q=assiniboia
# city not found
# 13/sataua
# http://api.openweathermap.org/data/2.5/weather?&q=sataua
# 13/yulara
# http://api.openweathermap.org/data/2.5/weather?&q=yulara
# 13/sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# 13/kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# 13/bengkulu
# http://api.openweathermap.org/data/2.5/weather?&q=bengkulu
# 13/arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# 13/holstebro
# http://api.openweathermap.org/data/2.5/weather?&q=holstebro
# 13/leningradskiy
# http://api.openweathermap.org/data/2.5/weather?&q=leningradskiy
# 13/tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# 13/chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?&q=chernyshevskiy
# 13/french harbor
# http://api.openweathermap.org/data/2.5/weather?&q=french harbor
# 13/hambantota
# http://api.openweathermap.org/data/2.5/weather?&q=hambantota
# 13/pisco
# http://api.openweathermap.org/data/2.5/weather?&q=pisco
# 13/omboue
# http://api.openweathermap.org/data/2.5/weather?&q=omboue
# 13/carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# 13/bay roberts
# http://api.openweathermap.org/data/2.5/weather?&q=bay roberts
# 13/muhororo
# http://api.openweathermap.org/data/2.5/weather?&q=muhororo
# 13/okhotsk
# http://api.openweathermap.org/data/2.5/weather?&q=okhotsk
# 13/upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# 13/peterhead
# http://api.openweathermap.org/data/2.5/weather?&q=peterhead
# 13/shestakovo
# http://api.openweathermap.org/data/2.5/weather?&q=shestakovo
# 13/nuuk
# http://api.openweathermap.org/data/2.5/weather?&q=nuuk
# 13/daru
# http://api.openweathermap.org/data/2.5/weather?&q=daru
# 13/mareeba
# http://api.openweathermap.org/data/2.5/weather?&q=mareeba
# 13/esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# 13/kodiak
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# 13/birin
# http://api.openweathermap.org/data/2.5/weather?&q=birin
# 13/vyazemskiy
# http://api.openweathermap.org/data/2.5/weather?&q=vyazemskiy
# 13/longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# city not found
# 14/kamenskoye
# http://api.openweathermap.org/data/2.5/weather?&q=kamenskoye
# 14/zyryanka
# http://api.openweathermap.org/data/2.5/weather?&q=zyryanka
# 14/qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?&q=qasigiannguit
# 14/ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# 14/thunder bay
# http://api.openweathermap.org/data/2.5/weather?&q=thunder bay
# 14/billings
# http://api.openweathermap.org/data/2.5/weather?&q=billings
# 14/mar del plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# 14/sharjah
# http://api.openweathermap.org/data/2.5/weather?&q=sharjah
# 14/bonfim
# http://api.openweathermap.org/data/2.5/weather?&q=bonfim
# city not found
# 15/tuggurt
# http://api.openweathermap.org/data/2.5/weather?&q=tuggurt
# 15/borogontsy
# http://api.openweathermap.org/data/2.5/weather?&q=borogontsy
# 15/bilibino
# http://api.openweathermap.org/data/2.5/weather?&q=bilibino
# 15/wasilla
# http://api.openweathermap.org/data/2.5/weather?&q=wasilla
# city not found
# 16/karaul
# http://api.openweathermap.org/data/2.5/weather?&q=karaul
# 16/hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# 16/brae
# http://api.openweathermap.org/data/2.5/weather?&q=brae
# 16/riohacha
# http://api.openweathermap.org/data/2.5/weather?&q=riohacha
# 16/birobidzhan
# http://api.openweathermap.org/data/2.5/weather?&q=birobidzhan
# 16/saint anthony
# http://api.openweathermap.org/data/2.5/weather?&q=saint anthony
# 16/east london
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# 16/north platte
# http://api.openweathermap.org/data/2.5/weather?&q=north platte
# 16/burnie
# http://api.openweathermap.org/data/2.5/weather?&q=burnie
# city not found
# 17/barentsburg
# http://api.openweathermap.org/data/2.5/weather?&q=barentsburg
# city not found
# 18/sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?&q=sentyabrskiy
# 18/rosetta
# http://api.openweathermap.org/data/2.5/weather?&q=rosetta
# 18/marawi
# http://api.openweathermap.org/data/2.5/weather?&q=marawi
# 18/batemans bay
# http://api.openweathermap.org/data/2.5/weather?&q=batemans bay
# 18/sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?&q=sao jose da coroa grande
# 18/severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?&q=severo-yeniseyskiy
# 18/butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# 18/madang
# http://api.openweathermap.org/data/2.5/weather?&q=madang
# 18/bayji
# http://api.openweathermap.org/data/2.5/weather?&q=bayji
# 18/ouadda
# http://api.openweathermap.org/data/2.5/weather?&q=ouadda
# 18/ngunguru
# http://api.openweathermap.org/data/2.5/weather?&q=ngunguru
# 18/iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# 18/grand gaube
# http://api.openweathermap.org/data/2.5/weather?&q=grand gaube
# 18/wangkui
# http://api.openweathermap.org/data/2.5/weather?&q=wangkui
# 18/karakol
# http://api.openweathermap.org/data/2.5/weather?&q=karakol
# 18/fuling
# http://api.openweathermap.org/data/2.5/weather?&q=fuling
# 18/fort saint james
# http://api.openweathermap.org/data/2.5/weather?&q=fort saint james
# 18/port elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# 18/vallenar
# http://api.openweathermap.org/data/2.5/weather?&q=vallenar
# 18/sabang
# http://api.openweathermap.org/data/2.5/weather?&q=sabang
# 18/tevaitoa
# http://api.openweathermap.org/data/2.5/weather?&q=tevaitoa
# 18/ballina
# http://api.openweathermap.org/data/2.5/weather?&q=ballina
# city not found
# 19/ondorhaan
# http://api.openweathermap.org/data/2.5/weather?&q=ondorhaan
# 19/luganville
# http://api.openweathermap.org/data/2.5/weather?&q=luganville
# 19/ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?&q=ust-tsilma
# city not found
# 20/nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?&q=nizhneyansk
# 20/bikin
# http://api.openweathermap.org/data/2.5/weather?&q=bikin
# 20/los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# 20/qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# 20/petrolina
# http://api.openweathermap.org/data/2.5/weather?&q=petrolina
# 20/ahipara
# http://api.openweathermap.org/data/2.5/weather?&q=ahipara
# 20/sola
# http://api.openweathermap.org/data/2.5/weather?&q=sola
# 20/touros
# http://api.openweathermap.org/data/2.5/weather?&q=touros
# 20/huanren
# http://api.openweathermap.org/data/2.5/weather?&q=huanren
# 20/lavrentiya
# http://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# 20/lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# 20/san patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# 20/san vicente
# http://api.openweathermap.org/data/2.5/weather?&q=san vicente
# 20/talnakh
# http://api.openweathermap.org/data/2.5/weather?&q=talnakh
# city not found
# 21/jujuy
# http://api.openweathermap.org/data/2.5/weather?&q=jujuy
# 21/pandan
# http://api.openweathermap.org/data/2.5/weather?&q=pandan
# 21/eyl
# http://api.openweathermap.org/data/2.5/weather?&q=eyl
# 21/vao
# http://api.openweathermap.org/data/2.5/weather?&q=vao
# 21/port lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# 21/ca mau
# http://api.openweathermap.org/data/2.5/weather?&q=ca mau
# 21/quatre cocos
# http://api.openweathermap.org/data/2.5/weather?&q=quatre cocos
# 21/codrington
# http://api.openweathermap.org/data/2.5/weather?&q=codrington
# 21/merta
# http://api.openweathermap.org/data/2.5/weather?&q=merta
# 21/novopokrovka
# http://api.openweathermap.org/data/2.5/weather?&q=novopokrovka
# 21/guia de isora
# http://api.openweathermap.org/data/2.5/weather?&q=guia de isora
# 21/bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# 21/polasara
# http://api.openweathermap.org/data/2.5/weather?&q=polasara
# 21/skibbereen
# http://api.openweathermap.org/data/2.5/weather?&q=skibbereen
# 21/pemba
# http://api.openweathermap.org/data/2.5/weather?&q=pemba
# city not found
# 22/mys shmidta
# http://api.openweathermap.org/data/2.5/weather?&q=mys shmidta
# 22/vardo
# http://api.openweathermap.org/data/2.5/weather?&q=vardo
# 22/yabrud
# http://api.openweathermap.org/data/2.5/weather?&q=yabrud
# 22/nishihara
# http://api.openweathermap.org/data/2.5/weather?&q=nishihara
# 22/karapyshi
# http://api.openweathermap.org/data/2.5/weather?&q=karapyshi
# 22/vostok
# http://api.openweathermap.org/data/2.5/weather?&q=vostok
# 22/kaduqli
# http://api.openweathermap.org/data/2.5/weather?&q=kaduqli
# 22/jaciara
# http://api.openweathermap.org/data/2.5/weather?&q=jaciara
# 22/bahia honda
# http://api.openweathermap.org/data/2.5/weather?&q=bahia honda
# city not found
# 23/marcona
# http://api.openweathermap.org/data/2.5/weather?&q=marcona
# 23/palmer
# http://api.openweathermap.org/data/2.5/weather?&q=palmer
# 23/wajima
# http://api.openweathermap.org/data/2.5/weather?&q=wajima
# 23/kirakira
# http://api.openweathermap.org/data/2.5/weather?&q=kirakira
# 23/necochea
# http://api.openweathermap.org/data/2.5/weather?&q=necochea
# 23/ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# 23/aksarka
# http://api.openweathermap.org/data/2.5/weather?&q=aksarka
# 23/mahebourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# 23/lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# 23/paciran
# http://api.openweathermap.org/data/2.5/weather?&q=paciran
# 23/yining
# http://api.openweathermap.org/data/2.5/weather?&q=yining
# 23/saposoa
# http://api.openweathermap.org/data/2.5/weather?&q=saposoa
# 23/padang
# http://api.openweathermap.org/data/2.5/weather?&q=padang
# 23/pyaozerskiy
# http://api.openweathermap.org/data/2.5/weather?&q=pyaozerskiy
# 23/lakatoro
# http://api.openweathermap.org/data/2.5/weather?&q=lakatoro
# 23/mayumba
# http://api.openweathermap.org/data/2.5/weather?&q=mayumba
# 23/mandalgovi
# http://api.openweathermap.org/data/2.5/weather?&q=mandalgovi
# 23/zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?&q=zapolyarnyy
# 23/onokhoy
# http://api.openweathermap.org/data/2.5/weather?&q=onokhoy
# 23/butiama
# http://api.openweathermap.org/data/2.5/weather?&q=butiama
# 23/fare
# http://api.openweathermap.org/data/2.5/weather?&q=fare
# 23/pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# 23/saint george
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# 23/bloomfield
# http://api.openweathermap.org/data/2.5/weather?&q=bloomfield
# 23/baruun-urt
# http://api.openweathermap.org/data/2.5/weather?&q=baruun-urt
# 23/kuryk
# http://api.openweathermap.org/data/2.5/weather?&q=kuryk
# 23/palomares
# http://api.openweathermap.org/data/2.5/weather?&q=palomares
# 23/port blair
# http://api.openweathermap.org/data/2.5/weather?&q=port blair
# city not found
# 24/palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?&q=palabuhanratu
# 24/cayenne
# http://api.openweathermap.org/data/2.5/weather?&q=cayenne
# 24/baykit
# http://api.openweathermap.org/data/2.5/weather?&q=baykit
# 24/mwinilunga
# http://api.openweathermap.org/data/2.5/weather?&q=mwinilunga
# 24/labuhan
# http://api.openweathermap.org/data/2.5/weather?&q=labuhan
# 24/ankazoabo
# http://api.openweathermap.org/data/2.5/weather?&q=ankazoabo
# city not found
# 25/ijaki
# http://api.openweathermap.org/data/2.5/weather?&q=ijaki
# 25/ulaangom
# http://api.openweathermap.org/data/2.5/weather?&q=ulaangom
# 25/poya
# http://api.openweathermap.org/data/2.5/weather?&q=poya
# 25/thanh hoa
# http://api.openweathermap.org/data/2.5/weather?&q=thanh hoa
# 25/ampanihy
# http://api.openweathermap.org/data/2.5/weather?&q=ampanihy
# 25/tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# 25/chuy
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# 25/anamur
# http://api.openweathermap.org/data/2.5/weather?&q=anamur
# 25/flinders
# http://api.openweathermap.org/data/2.5/weather?&q=flinders
# 25/calama
# http://api.openweathermap.org/data/2.5/weather?&q=calama
# 25/chunoyar
# http://api.openweathermap.org/data/2.5/weather?&q=chunoyar
# 25/homer
# http://api.openweathermap.org/data/2.5/weather?&q=homer
# 25/saint-francois
# http://api.openweathermap.org/data/2.5/weather?&q=saint-francois
# 25/maraa
# http://api.openweathermap.org/data/2.5/weather?&q=maraa
# 25/saint-pierre
# http://api.openweathermap.org/data/2.5/weather?&q=saint-pierre
# 25/bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# 25/hobyo
# http://api.openweathermap.org/data/2.5/weather?&q=hobyo
# 25/roseau
# http://api.openweathermap.org/data/2.5/weather?&q=roseau
# 25/buraydah
# http://api.openweathermap.org/data/2.5/weather?&q=buraydah
# 25/kyabe
# http://api.openweathermap.org/data/2.5/weather?&q=kyabe
# 25/stokmarknes
# http://api.openweathermap.org/data/2.5/weather?&q=stokmarknes
# 25/kavaratti
# http://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# 25/alofi
# http://api.openweathermap.org/data/2.5/weather?&q=alofi
# 25/jumla
# http://api.openweathermap.org/data/2.5/weather?&q=jumla
# 25/belfast
# http://api.openweathermap.org/data/2.5/weather?&q=belfast
# 25/csengod
# http://api.openweathermap.org/data/2.5/weather?&q=csengod
# 25/vila velha
# http://api.openweathermap.org/data/2.5/weather?&q=vila velha
# 25/marfino
# http://api.openweathermap.org/data/2.5/weather?&q=marfino
# 25/pauini
# http://api.openweathermap.org/data/2.5/weather?&q=pauini
# 25/raufoss
# http://api.openweathermap.org/data/2.5/weather?&q=raufoss
# 25/george town
# http://api.openweathermap.org/data/2.5/weather?&q=george town
# 25/rundu
# http://api.openweathermap.org/data/2.5/weather?&q=rundu
# 25/meulaboh
# http://api.openweathermap.org/data/2.5/weather?&q=meulaboh
# 25/samarai
# http://api.openweathermap.org/data/2.5/weather?&q=samarai
# 25/band
# http://api.openweathermap.org/data/2.5/weather?&q=band
# 25/roma
# http://api.openweathermap.org/data/2.5/weather?&q=roma
# 25/skala fourkas
# http://api.openweathermap.org/data/2.5/weather?&q=skala fourkas
# 25/hasaki
# http://api.openweathermap.org/data/2.5/weather?&q=hasaki
# 25/lima
# http://api.openweathermap.org/data/2.5/weather?&q=lima
# city not found
# 26/grand river south east
# http://api.openweathermap.org/data/2.5/weather?&q=grand river south east
# city not found
# 27/tsihombe
# http://api.openweathermap.org/data/2.5/weather?&q=tsihombe
# 27/kindersley
# http://api.openweathermap.org/data/2.5/weather?&q=kindersley
# 27/solnechnyy
# http://api.openweathermap.org/data/2.5/weather?&q=solnechnyy
# 27/gragnano
# http://api.openweathermap.org/data/2.5/weather?&q=gragnano
# 27/columbus
# http://api.openweathermap.org/data/2.5/weather?&q=columbus
# 27/norman wells
# http://api.openweathermap.org/data/2.5/weather?&q=norman wells
# 27/viedma
# http://api.openweathermap.org/data/2.5/weather?&q=viedma
# 27/cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# 27/quzhou
# http://api.openweathermap.org/data/2.5/weather?&q=quzhou
# 27/ayan
# http://api.openweathermap.org/data/2.5/weather?&q=ayan
# 27/aloleng
# http://api.openweathermap.org/data/2.5/weather?&q=aloleng
# 27/coralville
# http://api.openweathermap.org/data/2.5/weather?&q=coralville
# 27/ustka
# http://api.openweathermap.org/data/2.5/weather?&q=ustka
# 27/batagay
# http://api.openweathermap.org/data/2.5/weather?&q=batagay
# 27/kalianget
# http://api.openweathermap.org/data/2.5/weather?&q=kalianget
# 27/hokota
# http://api.openweathermap.org/data/2.5/weather?&q=hokota
# 27/fukue
# http://api.openweathermap.org/data/2.5/weather?&q=fukue
# 27/hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# 27/koungou
# http://api.openweathermap.org/data/2.5/weather?&q=koungou
# 27/nha trang
# http://api.openweathermap.org/data/2.5/weather?&q=nha trang
# 27/sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?&q=sao gabriel da cachoeira
# 27/juuru
# http://api.openweathermap.org/data/2.5/weather?&q=juuru
# 27/bambous virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# 27/lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# 27/mayna
# http://api.openweathermap.org/data/2.5/weather?&q=mayna
# 27/karratha
# http://api.openweathermap.org/data/2.5/weather?&q=karratha
# 27/nyurba
# http://api.openweathermap.org/data/2.5/weather?&q=nyurba
# 27/kargasok
# http://api.openweathermap.org/data/2.5/weather?&q=kargasok
# 27/kiama
# http://api.openweathermap.org/data/2.5/weather?&q=kiama
# 27/zakamensk
# http://api.openweathermap.org/data/2.5/weather?&q=zakamensk
# 27/praia
# http://api.openweathermap.org/data/2.5/weather?&q=praia
# city not found
# 28/jiddah
# http://api.openweathermap.org/data/2.5/weather?&q=jiddah
# 28/pingliang
# http://api.openweathermap.org/data/2.5/weather?&q=pingliang
# 28/yerbogachen
# http://api.openweathermap.org/data/2.5/weather?&q=yerbogachen
# 28/inhambane
# http://api.openweathermap.org/data/2.5/weather?&q=inhambane
# 28/catamarca
# http://api.openweathermap.org/data/2.5/weather?&q=catamarca
# 28/mauguio
# http://api.openweathermap.org/data/2.5/weather?&q=mauguio
# 28/shache
# http://api.openweathermap.org/data/2.5/weather?&q=shache
# 28/vicuna
# http://api.openweathermap.org/data/2.5/weather?&q=vicuna
# city not found
# 29/samusu
# http://api.openweathermap.org/data/2.5/weather?&q=samusu
# 29/berezanka
# http://api.openweathermap.org/data/2.5/weather?&q=berezanka
# 29/deputatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# 29/freetown
# http://api.openweathermap.org/data/2.5/weather?&q=freetown
# city not found
# 30/cheuskiny
# http://api.openweathermap.org/data/2.5/weather?&q=cheuskiny
# 30/dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# 30/san felipe
# http://api.openweathermap.org/data/2.5/weather?&q=san felipe
# 30/puerto escondido
# http://api.openweathermap.org/data/2.5/weather?&q=puerto escondido
# city not found
# 31/dubenskiy
# http://api.openweathermap.org/data/2.5/weather?&q=dubenskiy
# 31/kijang
# http://api.openweathermap.org/data/2.5/weather?&q=kijang
# 31/ambilobe
# http://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# 31/college
# http://api.openweathermap.org/data/2.5/weather?&q=college
# 31/reoti
# http://api.openweathermap.org/data/2.5/weather?&q=reoti
# 31/altamont
# http://api.openweathermap.org/data/2.5/weather?&q=altamont
# 31/filingue
# http://api.openweathermap.org/data/2.5/weather?&q=filingue
# 31/tessaoua
# http://api.openweathermap.org/data/2.5/weather?&q=tessaoua
# 31/durant
# http://api.openweathermap.org/data/2.5/weather?&q=durant
# 31/banda aceh
# http://api.openweathermap.org/data/2.5/weather?&q=banda aceh
# 31/trenggalek
# http://api.openweathermap.org/data/2.5/weather?&q=trenggalek
# 31/nizwa
# http://api.openweathermap.org/data/2.5/weather?&q=nizwa
# 31/tual
# http://api.openweathermap.org/data/2.5/weather?&q=tual
# 31/riverton
# http://api.openweathermap.org/data/2.5/weather?&q=riverton
# 31/gander
# http://api.openweathermap.org/data/2.5/weather?&q=gander
# 31/hokitika
# http://api.openweathermap.org/data/2.5/weather?&q=hokitika
# 31/marsala
# http://api.openweathermap.org/data/2.5/weather?&q=marsala
# 31/port-gentil
# http://api.openweathermap.org/data/2.5/weather?&q=port-gentil
# 31/ryotsu
# http://api.openweathermap.org/data/2.5/weather?&q=ryotsu
# city not found
# 32/mentok
# http://api.openweathermap.org/data/2.5/weather?&q=mentok
# 32/north bend
# http://api.openweathermap.org/data/2.5/weather?&q=north bend
# 32/ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?&q=ugoofaaru
# 32/northam
# http://api.openweathermap.org/data/2.5/weather?&q=northam
# 32/anadyr
# http://api.openweathermap.org/data/2.5/weather?&q=anadyr
# city not found
# 33/puunsi
# http://api.openweathermap.org/data/2.5/weather?&q=puunsi
# city not found
# 34/karamea
# http://api.openweathermap.org/data/2.5/weather?&q=karamea
# 34/staroye drozhzhanoye
# http://api.openweathermap.org/data/2.5/weather?&q=staroye drozhzhanoye
# 34/nenjiang
# http://api.openweathermap.org/data/2.5/weather?&q=nenjiang
# 34/sinnamary
# http://api.openweathermap.org/data/2.5/weather?&q=sinnamary
# 34/sogod
# http://api.openweathermap.org/data/2.5/weather?&q=sogod
# 34/aykhal
# http://api.openweathermap.org/data/2.5/weather?&q=aykhal
# 34/camabatela
# http://api.openweathermap.org/data/2.5/weather?&q=camabatela
# 34/santa rita
# http://api.openweathermap.org/data/2.5/weather?&q=santa rita
# 34/dunedin
# http://api.openweathermap.org/data/2.5/weather?&q=dunedin
# city not found
# 35/urdzhar
# http://api.openweathermap.org/data/2.5/weather?&q=urdzhar
# 35/klaksvik
# http://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# 35/goderich
# http://api.openweathermap.org/data/2.5/weather?&q=goderich
# city not found
# 36/umzimvubu
# http://api.openweathermap.org/data/2.5/weather?&q=umzimvubu
# 36/svetlyy
# http://api.openweathermap.org/data/2.5/weather?&q=svetlyy
# 36/chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# 36/sorland
# http://api.openweathermap.org/data/2.5/weather?&q=sorland
# 36/alexandria
# http://api.openweathermap.org/data/2.5/weather?&q=alexandria
# 36/nador
# http://api.openweathermap.org/data/2.5/weather?&q=nador
# 36/huarmey
# http://api.openweathermap.org/data/2.5/weather?&q=huarmey
# 36/pajapan
# http://api.openweathermap.org/data/2.5/weather?&q=pajapan
# 36/kloulklubed
# http://api.openweathermap.org/data/2.5/weather?&q=kloulklubed
# 36/aswan
# http://api.openweathermap.org/data/2.5/weather?&q=aswan
# city not found
# 37/attawapiskat
# http://api.openweathermap.org/data/2.5/weather?&q=attawapiskat
# 37/egvekinot
# http://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# 37/general roca
# http://api.openweathermap.org/data/2.5/weather?&q=general roca
# 37/bowen
# http://api.openweathermap.org/data/2.5/weather?&q=bowen
# 37/rio piracicaba
# http://api.openweathermap.org/data/2.5/weather?&q=rio piracicaba
# 37/bahia de caraquez
# http://api.openweathermap.org/data/2.5/weather?&q=bahia de caraquez
# 37/dzhebariki-khaya
# http://api.openweathermap.org/data/2.5/weather?&q=dzhebariki-khaya
# 37/westport
# http://api.openweathermap.org/data/2.5/weather?&q=westport
# 37/guiren
# http://api.openweathermap.org/data/2.5/weather?&q=guiren
# 37/kawalu
# http://api.openweathermap.org/data/2.5/weather?&q=kawalu
# 37/gao
# http://api.openweathermap.org/data/2.5/weather?&q=gao
# 37/wajir
# http://api.openweathermap.org/data/2.5/weather?&q=wajir
# 37/sioux lookout
# http://api.openweathermap.org/data/2.5/weather?&q=sioux lookout
# 37/oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?&q=oktyabrskoye
# 37/vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# 37/roald
# http://api.openweathermap.org/data/2.5/weather?&q=roald
# 37/joshimath
# http://api.openweathermap.org/data/2.5/weather?&q=joshimath
# 37/taltal
# http://api.openweathermap.org/data/2.5/weather?&q=taltal
# 37/lensk
# http://api.openweathermap.org/data/2.5/weather?&q=lensk
# 37/jinchang
# http://api.openweathermap.org/data/2.5/weather?&q=jinchang
# 37/sur
# http://api.openweathermap.org/data/2.5/weather?&q=sur
# 37/ler
# http://api.openweathermap.org/data/2.5/weather?&q=ler
# 37/strezhevoy
# http://api.openweathermap.org/data/2.5/weather?&q=strezhevoy
# city not found
# 38/toliary
# http://api.openweathermap.org/data/2.5/weather?&q=toliary
# 38/lawton
# http://api.openweathermap.org/data/2.5/weather?&q=lawton
# 38/mongagua
# http://api.openweathermap.org/data/2.5/weather?&q=mongagua
# 38/manbij
# http://api.openweathermap.org/data/2.5/weather?&q=manbij
# 38/port moresby
# http://api.openweathermap.org/data/2.5/weather?&q=port moresby
# 38/lata
# http://api.openweathermap.org/data/2.5/weather?&q=lata
# 38/somerset east
# http://api.openweathermap.org/data/2.5/weather?&q=somerset east
# 38/myitkyina
# http://api.openweathermap.org/data/2.5/weather?&q=myitkyina
# 38/kachiry
# http://api.openweathermap.org/data/2.5/weather?&q=kachiry
# 38/kantilo
# http://api.openweathermap.org/data/2.5/weather?&q=kantilo
# 38/anori
# http://api.openweathermap.org/data/2.5/weather?&q=anori
# city not found
# 39/tumannyy
# http://api.openweathermap.org/data/2.5/weather?&q=tumannyy
# 39/ondjiva
# http://api.openweathermap.org/data/2.5/weather?&q=ondjiva
# 39/hohhot
# http://api.openweathermap.org/data/2.5/weather?&q=hohhot
# 39/hondo
# http://api.openweathermap.org/data/2.5/weather?&q=hondo
# 39/port macquarie
# http://api.openweathermap.org/data/2.5/weather?&q=port macquarie
# 39/pivka
# http://api.openweathermap.org/data/2.5/weather?&q=pivka
# city not found
# 40/phrai bung
# http://api.openweathermap.org/data/2.5/weather?&q=phrai bung
# 40/san onofre
# http://api.openweathermap.org/data/2.5/weather?&q=san onofre
# 40/linping
# http://api.openweathermap.org/data/2.5/weather?&q=linping
# 40/todos santos
# http://api.openweathermap.org/data/2.5/weather?&q=todos santos
# 40/chinhoyi
# http://api.openweathermap.org/data/2.5/weather?&q=chinhoyi
# 40/urucara
# http://api.openweathermap.org/data/2.5/weather?&q=urucara
# 40/itoman
# http://api.openweathermap.org/data/2.5/weather?&q=itoman
# 40/namibe
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# 40/porto novo
# http://api.openweathermap.org/data/2.5/weather?&q=porto novo
# 40/liverpool
# http://api.openweathermap.org/data/2.5/weather?&q=liverpool
# 40/tura
# http://api.openweathermap.org/data/2.5/weather?&q=tura
# 40/ewa beach
# http://api.openweathermap.org/data/2.5/weather?&q=ewa beach
# 40/agbor
# http://api.openweathermap.org/data/2.5/weather?&q=agbor
# 40/giaveno
# http://api.openweathermap.org/data/2.5/weather?&q=giaveno
# 40/bama
# http://api.openweathermap.org/data/2.5/weather?&q=bama
# 40/verkhniy landekh
# http://api.openweathermap.org/data/2.5/weather?&q=verkhniy landekh
# 40/asau
# http://api.openweathermap.org/data/2.5/weather?&q=asau
# 40/novosheshminsk
# http://api.openweathermap.org/data/2.5/weather?&q=novosheshminsk
# 40/movileni
# http://api.openweathermap.org/data/2.5/weather?&q=movileni
# 40/horlivka
# http://api.openweathermap.org/data/2.5/weather?&q=horlivka
# 40/cariamanga
# http://api.openweathermap.org/data/2.5/weather?&q=cariamanga
# 40/ukrayinka
# http://api.openweathermap.org/data/2.5/weather?&q=ukrayinka
# 40/nakamura
# http://api.openweathermap.org/data/2.5/weather?&q=nakamura
# 40/uruzgan
# http://api.openweathermap.org/data/2.5/weather?&q=uruzgan
# 40/betzdorf
# http://api.openweathermap.org/data/2.5/weather?&q=betzdorf
# 40/te anau
# http://api.openweathermap.org/data/2.5/weather?&q=te anau
# 40/aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# 40/pochutla
# http://api.openweathermap.org/data/2.5/weather?&q=pochutla
# 40/raga
# http://api.openweathermap.org/data/2.5/weather?&q=raga
# 40/san isidro
# http://api.openweathermap.org/data/2.5/weather?&q=san isidro
# 40/fria
# http://api.openweathermap.org/data/2.5/weather?&q=fria
# 40/caborca
# http://api.openweathermap.org/data/2.5/weather?&q=caborca
# city not found
# 41/viligili
# http://api.openweathermap.org/data/2.5/weather?&q=viligili
# 41/mount isa
# http://api.openweathermap.org/data/2.5/weather?&q=mount isa
# 41/yatou
# http://api.openweathermap.org/data/2.5/weather?&q=yatou
# 41/agirish
# http://api.openweathermap.org/data/2.5/weather?&q=agirish
# 41/sarakhs
# http://api.openweathermap.org/data/2.5/weather?&q=sarakhs
# 41/boffa
# http://api.openweathermap.org/data/2.5/weather?&q=boffa
# 41/nome
# http://api.openweathermap.org/data/2.5/weather?&q=nome
# 41/moranbah
# http://api.openweathermap.org/data/2.5/weather?&q=moranbah
# 41/half moon bay
# http://api.openweathermap.org/data/2.5/weather?&q=half moon bay
# 41/srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# 41/itarema
# http://api.openweathermap.org/data/2.5/weather?&q=itarema
# 41/matagami
# http://api.openweathermap.org/data/2.5/weather?&q=matagami
# city not found
# 42/tarudant
# http://api.openweathermap.org/data/2.5/weather?&q=tarudant
# 42/mandera
# http://api.openweathermap.org/data/2.5/weather?&q=mandera
# 42/ajdabiya
# http://api.openweathermap.org/data/2.5/weather?&q=ajdabiya
# 42/fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# 42/nsoko
# http://api.openweathermap.org/data/2.5/weather?&q=nsoko
# 42/mangaratiba
# http://api.openweathermap.org/data/2.5/weather?&q=mangaratiba
# 42/fairbanks
# http://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# 42/antofagasta
# http://api.openweathermap.org/data/2.5/weather?&q=antofagasta
# 42/hirado
# http://api.openweathermap.org/data/2.5/weather?&q=hirado
# 42/campo maior
# http://api.openweathermap.org/data/2.5/weather?&q=campo maior
# 42/xucheng
# http://api.openweathermap.org/data/2.5/weather?&q=xucheng
# 42/primorsk
# http://api.openweathermap.org/data/2.5/weather?&q=primorsk
# 42/guerrero negro
# http://api.openweathermap.org/data/2.5/weather?&q=guerrero negro
# 42/berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?&q=berdigestyakh
# 42/middelkerke
# http://api.openweathermap.org/data/2.5/weather?&q=middelkerke
# 42/nabire
# http://api.openweathermap.org/data/2.5/weather?&q=nabire
# 42/prieska
# http://api.openweathermap.org/data/2.5/weather?&q=prieska
# 42/panshi
# http://api.openweathermap.org/data/2.5/weather?&q=panshi
# city not found
# 43/dipkarpaz
# http://api.openweathermap.org/data/2.5/weather?&q=dipkarpaz
# 43/santa rosa
# http://api.openweathermap.org/data/2.5/weather?&q=santa rosa
# 43/jutai
# http://api.openweathermap.org/data/2.5/weather?&q=jutai
# 43/santa cruz
# http://api.openweathermap.org/data/2.5/weather?&q=santa cruz
# 43/uyovu
# http://api.openweathermap.org/data/2.5/weather?&q=uyovu
# 43/staryy nadym
# http://api.openweathermap.org/data/2.5/weather?&q=staryy nadym
# 43/kupang
# http://api.openweathermap.org/data/2.5/weather?&q=kupang
# 43/ojo caliente
# http://api.openweathermap.org/data/2.5/weather?&q=ojo caliente
# city not found
# 44/babanusah
# http://api.openweathermap.org/data/2.5/weather?&q=babanusah
# 44/micheweni
# http://api.openweathermap.org/data/2.5/weather?&q=micheweni
# city not found
# 45/saleaula
# http://api.openweathermap.org/data/2.5/weather?&q=saleaula
# 45/barahona
# http://api.openweathermap.org/data/2.5/weather?&q=barahona
# 45/cao bang
# http://api.openweathermap.org/data/2.5/weather?&q=cao bang
# 45/nueva rosita
# http://api.openweathermap.org/data/2.5/weather?&q=nueva rosita
# city not found
# 46/utiroa
# http://api.openweathermap.org/data/2.5/weather?&q=utiroa
# 46/gimbi
# http://api.openweathermap.org/data/2.5/weather?&q=gimbi
# 46/tarbagatay
# http://api.openweathermap.org/data/2.5/weather?&q=tarbagatay
# city not found
# 47/kuhestan
# http://api.openweathermap.org/data/2.5/weather?&q=kuhestan
# 47/ranfurly
# http://api.openweathermap.org/data/2.5/weather?&q=ranfurly
# 47/xiongyue
# http://api.openweathermap.org/data/2.5/weather?&q=xiongyue
# 47/ucluelet
# http://api.openweathermap.org/data/2.5/weather?&q=ucluelet
# 47/castlegar
# http://api.openweathermap.org/data/2.5/weather?&q=castlegar
# 47/cockburn town
# http://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# 47/coahuayana
# http://api.openweathermap.org/data/2.5/weather?&q=coahuayana
# city not found
# 48/dujuma
# http://api.openweathermap.org/data/2.5/weather?&q=dujuma
# 48/potiskum
# http://api.openweathermap.org/data/2.5/weather?&q=potiskum
# 48/rusape
# http://api.openweathermap.org/data/2.5/weather?&q=rusape
# 48/bubaque
# http://api.openweathermap.org/data/2.5/weather?&q=bubaque
# 48/rantoul
# http://api.openweathermap.org/data/2.5/weather?&q=rantoul
# 48/darnah
# http://api.openweathermap.org/data/2.5/weather?&q=darnah
# 48/salalah
# http://api.openweathermap.org/data/2.5/weather?&q=salalah
# 48/kindu
# http://api.openweathermap.org/data/2.5/weather?&q=kindu
# city not found
# 49/ambodifototra
# http://api.openweathermap.org/data/2.5/weather?&q=ambodifototra
# 49/askarovo
# http://api.openweathermap.org/data/2.5/weather?&q=askarovo
# 49/seoul
# http://api.openweathermap.org/data/2.5/weather?&q=seoul
# 49/ayagoz
# http://api.openweathermap.org/data/2.5/weather?&q=ayagoz
# 49/birao
# http://api.openweathermap.org/data/2.5/weather?&q=birao
# 49/isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# 49/cervo
# http://api.openweathermap.org/data/2.5/weather?&q=cervo
# 49/tamandare
# http://api.openweathermap.org/data/2.5/weather?&q=tamandare
# 49/gladstone
# http://api.openweathermap.org/data/2.5/weather?&q=gladstone
# 49/cairns
# http://api.openweathermap.org/data/2.5/weather?&q=cairns
# city not found
# 50/temaraia
# http://api.openweathermap.org/data/2.5/weather?&q=temaraia
# 50/gweru
# http://api.openweathermap.org/data/2.5/weather?&q=gweru
# 50/bereznik
# http://api.openweathermap.org/data/2.5/weather?&q=bereznik
# 50/panguna
# http://api.openweathermap.org/data/2.5/weather?&q=panguna
# 50/katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# 50/porangatu
# http://api.openweathermap.org/data/2.5/weather?&q=porangatu
# 50/ariguani
# http://api.openweathermap.org/data/2.5/weather?&q=ariguani
# 50/atar
# http://api.openweathermap.org/data/2.5/weather?&q=atar
# 50/abu dhabi
# http://api.openweathermap.org/data/2.5/weather?&q=abu dhabi
# 50/tezu
# http://api.openweathermap.org/data/2.5/weather?&q=tezu
# 50/gouyave
# http://api.openweathermap.org/data/2.5/weather?&q=gouyave
# 50/bolitoc
# http://api.openweathermap.org/data/2.5/weather?&q=bolitoc
# 50/jalu
# http://api.openweathermap.org/data/2.5/weather?&q=jalu
# 50/durango
# http://api.openweathermap.org/data/2.5/weather?&q=durango
# city not found
# 51/we
# http://api.openweathermap.org/data/2.5/weather?&q=we
# 51/isla mujeres
# http://api.openweathermap.org/data/2.5/weather?&q=isla mujeres
# 51/luwingu
# http://api.openweathermap.org/data/2.5/weather?&q=luwingu
# 51/camacha
# http://api.openweathermap.org/data/2.5/weather?&q=camacha
# 51/orgovany
# http://api.openweathermap.org/data/2.5/weather?&q=orgovany
# 51/vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# 51/mitchell
# http://api.openweathermap.org/data/2.5/weather?&q=mitchell
# 51/pesaro
# http://api.openweathermap.org/data/2.5/weather?&q=pesaro
# 51/vredendal
# http://api.openweathermap.org/data/2.5/weather?&q=vredendal
# 51/oxelosund
# http://api.openweathermap.org/data/2.5/weather?&q=oxelosund
# 51/nara
# http://api.openweathermap.org/data/2.5/weather?&q=nara
# 51/kurumkan
# http://api.openweathermap.org/data/2.5/weather?&q=kurumkan
# 51/tambura
# http://api.openweathermap.org/data/2.5/weather?&q=tambura
# city not found
# 52/sumbawa
# http://api.openweathermap.org/data/2.5/weather?&q=sumbawa
# 52/mingshui
# http://api.openweathermap.org/data/2.5/weather?&q=mingshui
# 52/nagato
# http://api.openweathermap.org/data/2.5/weather?&q=nagato
# 52/semkhoz
# http://api.openweathermap.org/data/2.5/weather?&q=semkhoz
# 52/pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?&q=pangkalanbuun
# 52/horn lake
# http://api.openweathermap.org/data/2.5/weather?&q=horn lake
# 52/bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?&q=bandarbeyla
# 52/clyde
# http://api.openweathermap.org/data/2.5/weather?&q=clyde
# 52/odweyne
# http://api.openweathermap.org/data/2.5/weather?&q=odweyne
# 52/kerema
# http://api.openweathermap.org/data/2.5/weather?&q=kerema
# 52/mount gambier
# http://api.openweathermap.org/data/2.5/weather?&q=mount gambier
# 52/japura
# http://api.openweathermap.org/data/2.5/weather?&q=japura
# 52/matay
# http://api.openweathermap.org/data/2.5/weather?&q=matay
# 52/carahue
# http://api.openweathermap.org/data/2.5/weather?&q=carahue
# 52/vanimo
# http://api.openweathermap.org/data/2.5/weather?&q=vanimo
# 52/najran
# http://api.openweathermap.org/data/2.5/weather?&q=najran
# 52/horadiz
# http://api.openweathermap.org/data/2.5/weather?&q=horadiz
# 52/the pas
# http://api.openweathermap.org/data/2.5/weather?&q=the pas
# 52/salisbury
# http://api.openweathermap.org/data/2.5/weather?&q=salisbury
# 52/steinbach
# http://api.openweathermap.org/data/2.5/weather?&q=steinbach
# 52/peterongan
# http://api.openweathermap.org/data/2.5/weather?&q=peterongan
# 52/magadan
# http://api.openweathermap.org/data/2.5/weather?&q=magadan
# 52/matale
# http://api.openweathermap.org/data/2.5/weather?&q=matale
# 52/phuket
# http://api.openweathermap.org/data/2.5/weather?&q=phuket

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata_dict = {"City": citynew,"Cloudiness":cloudiness, "Country":countries,"Date":dates, "Humidity": humidities,"Lat":lats, "Lng":lngs, "Max Temp": maxtemps,
"Wind Speed":windspeed}
city_df=pd.DataFrame(citydata_dict)
city_df.head()
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Malatya Province           0      TR  1596072190        33  38.50   38.00
# 1           Rikitea         100      PF  1596072184        85 -23.12 -134.97
# 2     Alta Floresta           0      BR  1596072452        41  -9.88  -56.09
# 3          Ilhabela         100      BR  1596072316        87 -23.78  -45.36
# 4       Grants Pass           1      US  1596072323        12  42.44 -123.33
#
#    Max Temp  Wind Speed
# 0    297.15        5.10
# 1    295.92        6.12
# 2    296.34        1.87
# 3    292.38        2.73
# 4    310.15        3.60

# %%
city_df.to_csv("outputcityweather.csv",index=False, header=True)
csvpath="outputcityweather.csv"
csvread=pd.read_csv(csvpath)
df=pd.DataFrame(csvread)
df
# Out:
#                     City  Cloudiness Country        Date  Humidity    Lat  \
# 0       Malatya Province           0      TR  1596072190        33  38.50
# 1                Rikitea         100      PF  1596072184        85 -23.12
# 2          Alta Floresta           0      BR  1596072452        41  -9.88
# 3               Ilhabela         100      BR  1596072316        87 -23.78
# 4            Grants Pass           1      US  1596072323        12  42.44
# ..                   ...         ...     ...         ...       ...    ...
# 554  Steinbach am Taunus           3      DE  1596072641        62  50.17
# 555           Peterongan           6      ID  1596072641        54  -7.54
# 556              Magadan          74      RU  1596072642        40  59.57
# 557               Matale          56      LK  1596072642        85   7.47
# 558               Phuket          75      TH  1596072447        94   8.00
#
#         Lng  Max Temp  Wind Speed
# 0     38.00    297.15        5.10
# 1   -134.97    295.92        6.12
# 2    -56.09    296.34        1.87
# 3    -45.36    292.38        2.73
# 4   -123.33    310.15        3.60
# ..      ...       ...         ...
# 554    8.57    294.26        3.10
# 555  112.28    300.09        3.21
# 556  150.80    290.27        7.19
# 557   80.62    296.31        2.91
# 558   98.25    303.15        1.00
#
# [559 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = df['Lat']
y_values = df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# %%
plt.savefig("lat_vs_temp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = df['Lat']
y_values = df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
plt.savefig("lat_vs_humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = df['Lat']
y_values = df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
plt.savefig("lat_vs_cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = df['Lat']
y_values = df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind speed')
plt.show()

# %%
plt.savefig("lat_vs_windspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northernhem = df[df["Lat"] >= 0.0]
northernhem.reset_index(inplace=True)
northernhem
# Out:
#      index                 City  Cloudiness Country        Date  Humidity  \
# 0        0     Malatya Province           0      TR  1596072190        33
# 1        4          Grants Pass           1      US  1596072323        12
# 2        9             Raduzhny         100      RU  1596072454        85
# 3       10            Jamestown          90      US  1596072454        78
# 4       12          Pangnirtung          99      CA  1596072454        74
# ..     ...                  ...         ...     ...         ...       ...
# 375    553            Salisbury          90      GB  1596072641        87
# 376    554  Steinbach am Taunus           3      DE  1596072641        62
# 377    556              Magadan          74      RU  1596072642        40
# 378    557               Matale          56      LK  1596072642        85
# 379    558               Phuket          75      TH  1596072447        94
#
#        Lat     Lng  Max Temp  Wind Speed
# 0    38.50   38.00    297.15        5.10
# 1    42.44 -123.33    310.15        3.60
# 2    62.10   77.47    284.56        1.80
# 3    42.10  -79.24    295.37        2.60
# 4    66.15  -65.71    285.61        1.55
# ..     ...     ...       ...         ...
# 375  51.07   -1.80    287.04        1.50
# 376  50.17    8.57    294.26        3.10
# 377  59.57  150.80    290.27        7.19
# 378   7.47   80.62    296.31        2.91
# 379   8.00   98.25    303.15        1.00
#
# [380 rows x 10 columns]

# %%
southernhem = df[df["Lat"] <= 0.0]
southernhem.reset_index(inplace=True)
southernhem
# Out:
#      index           City  Cloudiness Country        Date  Humidity    Lat  \
# 0        1        Rikitea         100      PF  1596072184        85 -23.12
# 1        2  Alta Floresta           0      BR  1596072452        41  -9.88
# 2        3       Ilhabela         100      BR  1596072316        87 -23.78
# 3        5         Avarua           1      CK  1596072248        83 -21.21
# 4        6        Iquique          90      CL  1596072452        67 -20.22
# ..     ...            ...         ...     ...         ...       ...    ...
# 174    545  Mount Gambier          90      AU  1596072633       100 -37.83
# 175    546         Japura          75      ID  1596072548        78  -0.32
# 176    548        Carahue         100      CL  1596072634       100 -38.70
# 177    549         Vanimo          59      PG  1596072640        63  -2.67
# 178    555     Peterongan           6      ID  1596072641        54  -7.54
#
#         Lng  Max Temp  Wind Speed
# 0   -134.97    295.92        6.12
# 1    -56.09    296.34        1.87
# 2    -45.36    292.38        2.73
# 3   -159.78    294.15        5.10
# 4    -70.14    289.15        2.10
# ..      ...       ...         ...
# 174  140.77    281.15        2.04
# 175  102.35    298.99        0.92
# 176  -73.17    275.15        1.50
# 177  141.30    303.30        3.00
# 178  112.28    300.09        3.21
#
# [179 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lineregress=st.linregress(northernhem['Lat'],northernhem['Max Temp'])
print(lineregress)
slope=-0.2521431210842786
intercept=304.90398409094297
x_values = northernhem['Lat']
y_values = northernhem['Max Temp']
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red", size="20")
plt.xlabel('Lat')
plt.ylabel('Temp')
plt.show()

plt.savefig("lat_vs_temNH.png")
# Out:
# LinregressResult(slope=-0.24531828863264638, intercept=304.6064942736726, rvalue=-0.680111549410954, pvalue=6.495922841413359e-53, stderr=0.013601043051665944)

# %%
lineregress=st.linregress(southernhem['Lat'],southernhem['Max Temp'])
print(lineregress)
slope=0.4288014973130267 
intercept=299.4140518971515
x_values = southernhem['Lat']
y_values = southernhem['Max Temp']
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Temp')
plt.show()

plt.savefig("lat_vs_temSH.png")
# Out:
# LinregressResult(slope=0.3970451822701409, intercept=299.5525438871766, rvalue=0.7509036126409543, pvalue=1.0165396908171607e-33, stderr=0.026247257845589504)

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lineregress=st.linregress(northernhem['Lat'],northernhem['Humidity'])
print(lineregress)
slope=-0.055397082659377254
intercept=73.3456039029042
x_values = northernhem['Lat']
y_values = northernhem['Humidity']
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Humidity')
plt.show()

plt.savefig("lat_vs_humNH.png")
# Out:
# LinregressResult(slope=-0.11728347984121519, intercept=77.20064927994386, rvalue=-0.12333436464291692, pvalue=0.016150378221459143, stderr=0.048537606471067564)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lineregress=st.linregress(southernhem['Lat'],southernhem['Humidity'])
print(lineregress)
slope=-0.11589904329804855
intercept=69.18384764540123
x_values = southernhem['Lat']
y_values = southernhem['Humidity']
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Humidity')
plt.show()

plt.savefig("lat_vs_humSH.png")
# Out:
# LinregressResult(slope=-0.038411534579878524, intercept=70.42536130075771, rvalue=-0.02880904951422942, pvalue=0.7018547196057989, stderr=0.10017648664262982)

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lineregress=st.linregress(northernhem['Lat'],northernhem['Cloudiness'])
print(lineregress)
slope=-0.14968380891248298
intercept=55.82901900792869
x_values = northernhem['Lat']
y_values = northernhem['Cloudiness']
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Cloudiness')
plt.show()
plt.savefig("lat_vs_windspeedNH.png")
# Out:
# LinregressResult(slope=-0.13431438188137076, intercept=54.80436848006739, rvalue=-0.06474325092478833, pvalue=0.2079429616989341, stderr=0.10648047715214645)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lineregress=st.linregress(southernhem['Lat'],southernhem['Cloudiness'])
print(lineregress)
slope=0.0859442668545403
intercept=40.69645203017407
x_values = southernhem['Lat']
y_values = southernhem['Cloudiness']
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red", size="20")
plt.xlabel('Lat')
plt.ylabel('Cloudiness')
plt.show()

plt.savefig("lat_vs_cloudinessSH.png")
# Out:
# LinregressResult(slope=-0.374541192806141, intercept=34.903663145051084, rvalue=-0.12510671173117752, pvalue=0.09518680959153869, stderr=0.2232578544925523)

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lineregress=st.linregress(northernhem['Lat'],northernhem['Wind Speed'])
print(lineregress)
slope=-0.005540405162775291
intercept=3.681337232251905
x_values = northernhem['Lat']
y_values = northernhem['Wind Speed']
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lat')
plt.ylabel('Wind Speed')
plt.show()
plt.savefig("lat_vs_windspeedNH.png")
# Out:
# LinregressResult(slope=-0.00501902921233561, intercept=3.5713066580344863, rvalue=-0.04471323590197811, pvalue=0.3847461213603849, stderr=0.005767706484773408)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lineregress=st.linregress(southernhem['Lat'],southernhem['Wind Speed'])
print(lineregress)
slope=0.004294083379959969
intercept=3.3388259410449543
x_values = southernhem['Lat']
y_values = southernhem['Wind Speed']
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red", size="20")
plt.xlabel('Lat')
plt.ylabel('Wind Speed')
plt.show()

plt.savefig("lat_vs_windspeedSH.png")
# Out:
# LinregressResult(slope=0.005862068487484025, intercept=3.5096626562900632, rvalue=0.03275940616888602, pvalue=0.6633176189455159, stderr=0.01344296510405782)
